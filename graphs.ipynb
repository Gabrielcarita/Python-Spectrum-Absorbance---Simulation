# %%
import autoreload
# %reload_ext autoreload
# %autoreload

import numpy as np
from numpy import *
from pandas import *
from seaborn import *
import matplotlib.pyplot as plt
import pandas as pd
import plotly.plotly as py
from statsmodels.formula.api import *
# %matplotlib inline

pd.options.display.max_columns = None
pd.options.display.max_seq_items = None
np.set_printoptions(threshold=np.inf)

# %%
transitions = read_csv('teste1.csv')

# %%
transitions2 = read_csv('teste2.csv')

# %%
transitions3 = read_csv('teste3.csv')

# %%
transitions4 = read_csv('teste4.csv')

# %%
transitions.shape
# Out:
# (251, 2)

# %%
transitions2.shape
# Out:
# (251, 2)

# %%
transitions3.shape
# Out:
# (251, 2)

# %%
transitions4.shape
# Out:
# (251, 2)

# %%
transitions.head(251)
# Out:
#       e_v   abs_e
# 0    2.00  235.78
# 1    2.02  240.79
# 2    2.04  245.98
# 3    2.06  251.34
# 4    2.08  256.89
# 5    2.10  262.63
# 6    2.12  268.57
# 7    2.14  274.73
# 8    2.16  281.10
# 9    2.18  287.72
# 10   2.20  294.58
# 11   2.22  301.69
# 12   2.24  309.08
# 13   2.26  316.76
# 14   2.28  324.74
# 15   2.30  333.04
# 16   2.32  341.67
# 17   2.34  350.66
# 18   2.36  360.02
# 19   2.38  369.78
# 20   2.40  379.96
# 21   2.42  390.59
# 22   2.44  401.68
# 23   2.46  413.28
# 24   2.48  425.40
# 25   2.50  438.09
# 26   2.52  451.38
# 27   2.54  465.32
# 28   2.56  479.93
# 29   2.58  495.27
# ..    ...     ...
# 221  6.42  523.64
# 222  6.44  505.35
# 223  6.46  488.07
# 224  6.48  471.73
# 225  6.50  456.25
# 226  6.52  441.57
# 227  6.54  427.65
# 228  6.56  414.41
# 229  6.58  401.83
# 230  6.60  389.85
# 231  6.62  378.44
# 232  6.64  367.56
# 233  6.66  357.17
# 234  6.68  347.25
# 235  6.70  337.77
# 236  6.72  328.69
# 237  6.74  320.01
# 238  6.76  311.69
# ...

# %%
transitions2.head(251)
# Out:
#      e_v2  abs_e2
# 0    2.00  233.97
# 1    2.02  238.90
# 2    2.04  244.00
# 3    2.06  249.26
# 4    2.08  254.71
# 5    2.10  260.35
# 6    2.12  266.18
# 7    2.14  272.22
# 8    2.16  278.48
# 9    2.18  284.96
# 10   2.20  291.69
# 11   2.22  298.66
# 12   2.24  305.90
# 13   2.26  313.42
# 14   2.28  321.23
# 15   2.30  329.35
# 16   2.32  337.79
# 17   2.34  346.58
# 18   2.36  355.73
# 19   2.38  365.26
# 20   2.40  375.20
# 21   2.42  385.57
# 22   2.44  396.39
# 23   2.46  407.70
# 24   2.48  419.51
# 25   2.50  431.87
# 26   2.52  444.81
# 27   2.54  458.36
# 28   2.56  472.57
# 29   2.58  487.47
# ..    ...     ...
# 221  6.42  569.51
# 222  6.44  548.73
# 223  6.46  529.15
# 224  6.48  510.66
# 225  6.50  493.20
# 226  6.52  476.67
# 227  6.54  461.03
# 228  6.56  446.19
# 229  6.58  432.11
# 230  6.60  418.73
# 231  6.62  406.01
# 232  6.64  393.90
# 233  6.66  382.37
# 234  6.68  371.37
# 235  6.70  360.87
# 236  6.72  350.84
# 237  6.74  341.25
# 238  6.76  332.08
# ...

# %%
transitions3.head(251)
# Out:
#      e_v3  abs_e3
# 0    2.00  235.78
# 1    2.02  240.79
# 2    2.04  245.98
# 3    2.06  251.34
# 4    2.08  256.89
# 5    2.10  262.63
# 6    2.12  268.57
# 7    2.14  274.73
# 8    2.16  281.10
# 9    2.18  287.72
# 10   2.20  294.58
# 11   2.22  301.69
# 12   2.24  309.08
# 13   2.26  316.76
# 14   2.28  324.74
# 15   2.30  333.04
# 16   2.32  341.67
# 17   2.34  350.66
# 18   2.36  360.02
# 19   2.38  369.78
# 20   2.40  379.96
# 21   2.42  390.59
# 22   2.44  401.68
# 23   2.46  413.28
# 24   2.48  425.40
# 25   2.50  438.09
# 26   2.52  451.38
# 27   2.54  465.32
# 28   2.56  479.93
# 29   2.58  495.27
# ..    ...     ...
# 221  6.42  523.64
# 222  6.44  505.35
# 223  6.46  488.07
# 224  6.48  471.73
# 225  6.50  456.25
# 226  6.52  441.57
# 227  6.54  427.65
# 228  6.56  414.41
# 229  6.58  401.83
# 230  6.60  389.85
# 231  6.62  378.44
# 232  6.64  367.56
# 233  6.66  357.17
# 234  6.68  347.25
# 235  6.70  337.77
# 236  6.72  328.69
# 237  6.74  320.01
# 238  6.76  311.69
# ...

# %%
transitions4.head(251)
# Out:
#      e_v4  abs_e4
# 0    2.00  235.78
# 1    2.02  240.79
# 2    2.04  245.98
# 3    2.06  251.34
# 4    2.08  256.89
# 5    2.10  262.63
# 6    2.12  268.57
# 7    2.14  274.73
# 8    2.16  281.10
# 9    2.18  287.72
# 10   2.20  294.58
# 11   2.22  301.69
# 12   2.24  309.08
# 13   2.26  316.76
# 14   2.28  324.74
# 15   2.30  333.04
# 16   2.32  341.67
# 17   2.34  350.66
# 18   2.36  360.02
# 19   2.38  369.78
# 20   2.40  379.96
# 21   2.42  390.59
# 22   2.44  401.68
# 23   2.46  413.28
# 24   2.48  425.40
# 25   2.50  438.09
# 26   2.52  451.38
# 27   2.54  465.32
# 28   2.56  479.93
# 29   2.58  495.27
# ..    ...     ...
# 221  6.42  523.64
# 222  6.44  505.35
# 223  6.46  488.07
# 224  6.48  471.73
# 225  6.50  456.25
# 226  6.52  441.57
# 227  6.54  427.65
# 228  6.56  414.41
# 229  6.58  401.83
# 230  6.60  389.85
# 231  6.62  378.44
# 232  6.64  367.56
# 233  6.66  357.17
# 234  6.68  347.25
# 235  6.70  337.77
# 236  6.72  328.69
# 237  6.74  320.01
# 238  6.76  311.69
# ...

# %%
transitions.columns
# Out:
# Index(['e_v', 'abs_e'], dtype='object')

# %%
transitions2.columns
# Out:
# Index(['e_v2', 'abs_e2'], dtype='object')

# %%
transitions3.columns
# Out:
# Index(['e_v3', 'abs_e3'], dtype='object')

# %%
transitions4.columns
# Out:
# Index(['e_v4', 'abs_e4'], dtype='object')

# %%
plt.plot(transitions.e_v , transitions.abs_e, 'k' ,linestyle='-' , antialiased=True , linewidth=3.3 ,label='CLFORM-6-311++G(d,p)' )

plt.plot(transitions2.e_v2 , transitions2.abs_e2,'b', linestyle='--' , antialiased=True , linewidth=3.3 ,label='CLFORM-6-31+G(d)')

plt.plot(transitions3.e_v3 , transitions3.abs_e3,'g', linestyle='dotted' , antialiased=True , linewidth=3.3 ,label='VACUUM-6-311++G(d,p)')

plt.plot(transitions4.e_v4 , transitions4.abs_e4 ,'r',linestyle=':' , antialiased=True , linewidth=3.3 ,label='VACUUM-6-31+G(d)')

plt.legend(loc='best')

plt.rc('grid', linestyle="-", color='black')
plt.axis([7,2,0,1.5E+4])

plt.grid(True)


plt.savefig('graficoteste.pdf')
